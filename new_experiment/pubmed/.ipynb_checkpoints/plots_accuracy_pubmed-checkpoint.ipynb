# %%
import collections
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_data(file_name):
    a = open(file_name, 'r')
    train_loss = collections.defaultdict(list)
    train_acc = collections.defaultdict(list)
    val_loss = collections.defaultdict(list)
    val_acc = collections.defaultdict(list)
    test_loss = []
    test_acc = []
    count = 0
    for line in a:
        line = line.split()
        if line[1] == 'train':
            train_loss[int(line[0])].append(float(line[2])) 
            train_acc[int(line[0])].append(float(line[3]))
        elif line[1] == 'val':
            val_loss[int(line[0])].append(float(line[2]))
            val_acc[int(line[0])].append(float(line[3]))
        elif line[1] == 'test':
            test_loss.append(float(line[2]))
            test_acc.append(float(line[3]))
            count += 1
        else:
            print("error")
    a.close()
    for key in train_loss.keys():
        
        train_loss[key] = np.array(train_loss[key]).sum() / len(train_loss[key])
        train_acc[key] = np.array(train_acc[key]).sum() / len(train_acc[key])
        val_loss[key] = np.array(val_loss[key]).sum() / len(val_loss[key])
        val_acc[key]  = np.array(val_acc[key]).sum() / len(val_acc[key])
    test_loss = np.array(test_loss).sum() / len(test_loss)
    test_acc = np.array(test_acc).sum() / len(test_acc)
    
    return train_loss, train_acc, val_loss, val_acc, test_loss, test_acc

# %%
def get_plot(file_name):
    train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
    
    #plt.plot(train_loss.keys(), train_loss.values(), label = 'train_loss')
    #print(train_acc.values())
    plt.plot(train_acc.keys(), train_acc.values(), label = 'train_acc')
    #plt.plot(val_loss.keys(), val_loss.values(), label = 'val_loss')
    plt.plot(val_acc.keys(), val_acc.values(), label = 'val_acc')
    plt.ylim(0, 1) 
    plt.xlim(0, 300) 
    plt.legend()
    plt.show()

# %%
def get_convergence_time(input_curve):
    converge_acc = list(input_curve.values())[-1]
    for acc_iter in input_curve:
         if acc_iter > 0:
            if abs(input_curve[acc_iter] - converge_acc) < 0.05:
                return acc_iter
    return len(input_curve)

# %%
#use 0.05 for convergence time

plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
print('Central')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.plot(train_acc.keys(), train_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_1.0_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)
print('0hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_1.0_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)
print('BDS')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_1.0_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)
print('1hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_1.0_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)
print('2hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 1.0', fontsize=25)
# naming the y axis
plt.ylabel('Train Accuracy', fontsize=25)

plt.ylim(0, 1.05) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("train_acc_IID_1.0.eps", format='eps')
# Out:
# Central
# 0.8683333333333332 0.6874 0.6745
# 70 58
# 0hop
# 0.8944444444444445 0.7311111111111112 0.7305555555555556
# 178 184
# BDS
# 0.9416666666666667 0.784 0.7738999999999999
# 75 79
# 1hop
# 0.9870370370370369 0.7735555555555556 0.7672222222222222
# 157 77
# 2hop
# 1.0 0.77525 0.7728750000000001
# 150 35
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)


plt.plot(val_acc.keys(), val_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_1.0_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_1.0_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)


file_name = "real_pubmed_IID_1.0_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_1.0_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 1.0', fontsize=25)
# naming the y axis
plt.ylabel('Validation Accuracy', fontsize=25)

plt.ylim(0, 0.8) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("test_acc_IID_1.0.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
print('Central')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.plot(train_acc.keys(), train_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.5_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)
print('0hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.5_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)
print('BDS')
print(train_acc[293], val_acc[293], test_acc)
#the curve deceases at the last iterations
#remove last iterations for better evaluation of convergence time
for i in range(294,300):
    train_acc.pop(i)
    val_acc.pop(i)

print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.5_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)
print('1hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.5_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)
print('2hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 0.5', fontsize=25)
# naming the y axis
plt.ylabel('Train Accuracy', fontsize=25)

plt.ylim(0, 1.05) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("train_acc_IID_0.5.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Central
# 0.8683333333333332 0.6874 0.6745
# 70 58
# 0hop
# 0.8944444444444445 0.7193333333333333 0.6993333333333333
# 115 92
# BDS
# 0.8833333333333333 0.789 0.6445000000000001
# 32 32
# 1hop
# 0.9722222222222222 0.7526666666666667 0.7376666666666667
# 144 57
# 2hop
# 0.9833333333333333 0.785 0.7665
# 43 50

# %%
plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)


plt.plot(val_acc.keys(), val_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.5_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.5_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)


file_name = "real_pubmed_IID_0.5_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.5_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 0.5', fontsize=25)
# naming the y axis
plt.ylabel('Validation Accuracy', fontsize=25)

plt.ylim(0, 0.8) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("test_acc_IID_0.5.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
print('Central')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.plot(train_acc.keys(), train_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.0_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)
print('0hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.0_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)
print('BDS')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.0_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)
print('1hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

file_name = "real_pubmed_IID_0.0_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(train_acc.keys(), train_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)
print('2hop')
print(train_acc[299], val_acc[299], test_acc)
print(get_convergence_time(train_acc), get_convergence_time(val_acc))

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 0.0', fontsize=25)
# naming the y axis
plt.ylabel('Train Accuracy', fontsize=25)

plt.ylim(0, 1.05) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("train_acc_IID_0.0.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Central
# 0.8683333333333332 0.6874 0.6745
# 102 72
# 0hop
# 0.8703703703703705 0.7051111111111112 0.6951111111111111
# 231 226
# BDS
# 0.9049999999999999 0.8092 0.7822000000000001
# 230 183
# 1hop
# 0.8458333333333334 0.65425 0.64375
# 248 31
# 2hop
# 0.8062499999999999 0.6332500000000001 0.622625
# 234 38

# %%
plt.style.use('seaborn-whitegrid')


file_name = "real_pubmed_IID_centralized_GCN_iter_300"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)


plt.plot(val_acc.keys(), val_acc.values(), 'v-', label = 'GCN', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.0_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 's-', label = 'FedGCN(0-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.0_1hop_BDS_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), 'o-', label = 'BDS-GCN', markevery=10, markersize=8)


file_name = "real_pubmed_IID_0.0_1hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '+-', label = 'FedGCN(1-hop)', markevery=10, markersize=8)

file_name = "real_pubmed_IID_0.0_2hop_Block_federated_GCN_iter_300_epoch_3_device_num_3"
train_loss, train_acc, val_loss, val_acc, test_loss, test_acc = get_data(file_name)
plt.plot(val_acc.keys(), val_acc.values(), '*-', label = 'FedGCN', markevery=10, markersize=8)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# naming the x axis
plt.xlabel('Iteration, IID = 0.0', fontsize=25)
# naming the y axis
plt.ylabel('Validation Accuracy', fontsize=25)

plt.ylim(0, 0.8) 
plt.xlim(0, 300) 
plt.legend(fontsize=20, frameon=True, loc='lower right')
#plt.title("Compare, IID, epoch = 3")
#plt.show()
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.savefig("test_acc_IID_0.0.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
